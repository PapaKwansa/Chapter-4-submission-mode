# %% [markdown]
# # deeptrack.backend.polynomials
#
# <a href="https://colab.research.google.com/github/DeepTrackAI/DeepTrack2/blob/develop/tutorials/3-advanced-topics/DTAT399D_polynomials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deeptrack  # Uncomment if running on Colab/Kaggle.
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.6/195.6 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 1.9 MB/s eta 0:00:00
# ...
#   Created wheel for lazy_import: filename=lazy_import-0.2.2-py2.py3-none-any.whl size=16496 sha256=1674dc57148ae100ad1e13cde405467d8b4de85e169cf1d0c25c07a093d357e9
#   Stored in directory: /root/.cache/pip/wheels/a4/71/2e/08ec0c8372739b0e20a7e48474312372031c5050d8c791c75f
# Successfully built lazy_import
# ...

# %% [markdown]
# This advanced tutorial introduces the module deeptrack.backend.polynomials.

# %%
import matplotlib.pyplot as plt
import numpy as np

from deeptrack.backend import polynomials
# Out:
# /usr/local/lib/python3.11/dist-packages/deeptrack/__init__.py:14: UserWarning: TensorFlow is detected in your environment. DeepTrack2 version 2.0++ no longer supports TensorFlow. If you need TensorFlow support, please install the legacy version 1.7 of DeepTrack2:
#
#     pip install deeptrack==1.7
#
# For more details, refer to the DeepTrack documentation.
#   warnings.warn(
# WARNING:pint.util:Redefining '[magnetic_flux]' (<class 'pint.delegates.txt_defparser.plain.DerivedDimensionDefinition'>)

# %% [markdown]
# ## 1. Introduction to Bessel and Riccati-Bessel Functions
#
# Bessel and Riccati-Bessel functions are important in many areas of physics and engineering, particularly in wave propagation, acoustics, and electromagnetism.
#
# ## 2. Computing Bessel Functions
#
# The functions `besselj` and `bessely` compute the Bessel functions of the first and second kind, respectively. These functions are solutions to Bessel's differential equation and appear in problems involving cylindrical symmetry.

# %%
x = np.linspace(0, 20, 100)

plt.figure(figsize=(8, 5))

for l in range(3):
    J_values = polynomials.besselj(l, x)
    plt.plot(x, J_values, label=f"Bessel J_{l}(x)")

plt.title("Bessel Functions of the First Kind")

plt.xlabel("x")
plt.xlim(0, 20)

plt.ylabel("Function Value")
plt.ylim(-1, 1)

plt.legend()
plt.grid()
plt.show()

# %%
x = np.linspace(0, 20, 100)

plt.figure(figsize=(8, 5))

for l in range(3):
    Y_values = polynomials.bessely(l, x)
    plt.plot(x, Y_values, label=f"Bessel Y_{l}(x)")

plt.title("Bessel Functions of the Second Kind")

plt.xlabel("x")
plt.xlim(0, 20)

plt.ylabel("Function Value")
plt.ylim(-1, 1)

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 3. Computing Riccati-Bessel Functions
#
# Riccati-Bessel functions are modified versions of Bessel functions, commonly used in scattering problems. The functions `ricbesj` and `ricbesy` compute the first and second kinds of Riccati-Bessel functions, respectively.

# %%
x = np.linspace(0, 20, 100)

plt.figure(figsize=(8, 5))

for l in range(3):
    RicJ_values = polynomials.ricbesj(l, x)
    plt.plot(x, RicJ_values, label=f"Riccati-Bessel J_{l}(x)")

plt.title("Riccati-Bessel Functions of the First Kind")

plt.xlabel("x")
plt.xlim(0, 20)

plt.ylabel("Function Value")
plt.ylim(-1.4, 1.4)

plt.legend()
plt.grid()
plt.show()

# %%
x = np.linspace(0, 20, 100)

plt.figure(figsize=(8, 5))

for l in range(3):
    RicY_values = polynomials.ricbesy(l, x)
    plt.plot(x, RicY_values, label=f"Riccati-Bessel Y_{l}(x)")

plt.title("Riccati-Bessel Functions of the Second Kind")

plt.xlabel("x")
plt.xlim(0, 20)

plt.ylabel("Function Value")
plt.ylim(-1.4, 1.4)

plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/deeptrack/backend/polynomials.py:190: RuntimeWarning: invalid value encountered in multiply
#   return -np.sqrt(np.pi * x / 2) * bessely(l + 0.5, x)
